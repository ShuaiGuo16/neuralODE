# %% [markdown]
# ### Objective
#
# In this notebook, we implement the **Neural ODE** approach to model a dynamical system described by the *ordinary differential equation* (ODE).

# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context("talk", font_scale=0.7)

import tensorflow as tf
from tensorflow import keras
tf.random.set_seed(42)

from scipy.integrate import solve_ivp
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error

# %% [markdown]
# ### 1. Target Dynamical System: Logistic Growth Model
#
# In this notebook, we investigate a specific dynamical system called [logistic growth system](https://services.math.duke.edu/education/ccp/materials/diffeq/logistic/logi1.html). This system is widely used in biology and ecology for modeling animal population growth under limited resources:
#
# \begin{equation}
# \frac{dp(t)}{dt} = rp(t)(1-\frac{p(t)}{k}) - H(p(t)).
# \end{equation}
#
# Here, $p(t)$ denotes the population size at time $t$, $r$ and $k$ represent the intrinsic growth rate of the population and carrying capacity of the environment, respectively.
#
# $H(\cdot)$ is a harvesting function and reflects the removal of the animal population due to harvesting (or culling). In the current study, we adopt the following expression for $H(\cdot)$:
#
# \begin{equation}
# H(p(t)) = min(h \cdot p, H_{max}),
# \end{equation}
#
# where harvesting is proportional to the population size (harvesting rate $h$), but is capped at a maximum value $H_{max}$, for the purpose of sustainable management.

# %%
def logistic_growth(t, p, r, k, h, H_max):
    """
    ODE for logistic growth model.
    
    Inputs:
    -------
    t: time
    p: population size
    r: intrinsic growth rate
    k: carrying capacity
    h: harvesting rate
    H_max: maximum harvesting capacity
    
    Output:
    -------
    dpdt: Change rate of population size.
    """
    
    dpdt = r*p*(1-p/k) - min(h*p, H_max)
    
    return dpdt

# %% [markdown]
# ### 2. Case Study: Dynamic Discovery
#
# In this section, we tackle the first case study, i.e., dynamic discovery.
#
# Here, we assume that while the harvesting function is known (controlled by human activity), the exact functional form that governs the *natural dynamics* of the population evolution remains unknown:
#
# \begin{equation}
# \frac{dp}{dt} = f_{unknown}(p) - min(h \cdot p, H_{max}).
# \end{equation}
#
# This case study has practical meaning as for real-world complex dynamica systems, it is often challenging to derive an explicit expression to describe the system dynamics. However, with the Neural ODE approach, we can potentially infer this underlying functional form from observational data.

# %% [markdown]
# #### 2.1 Strategy
#
# The key idea of identifying hidden dynamics in Neural ODE is to approximate the unknown function $f_{unknown}(p)$ with a neural network:
#
# \begin{equation}
# \frac{dp}{dt} = f_{NN}(p) - min(h \cdot p, H_{max}).
# \end{equation}
#
# By training the $f_{NN}(p)$ based on the observation data of $p$, we are able to obtain a predictive model that takes in the population size p, and outputs the population change induced by the natural dynamics, thus completing the ODE.

# %% [markdown]
# Since we can only observe the population size $p$ and not its derivative $dp/dt$, we need to find a way to approximate those derivatives to facilitate training. Fortunately, traditional numerical methods for solving ODE has provided us with a range of techniques to discretize the derivatives. In this study, we opt for a simple Euler scheme to approximate the $dp/dt$ term:
#
# \begin{equation}
# \frac{dp}{dt} = \frac{p_{i+1}-p_{i}}{\Delta t},
# \end{equation}
#
# where $p_{i}$ and $p_{i+1}$ indicate the population size at the current and subsequent time steps, respectively, and $\Delta t$ denotes the time interval between these steps. We can then substitute this discretized version of $dp/dt$ back into the ODE:
#
# \begin{equation}
# \frac{p_{i+1}-p_{i}}{\Delta t} = f_{NN}(p_{i}) - min(h \cdot p_{i}, H_{max}).
# \end{equation}

# %% [markdown]
# #### 2.2 Data Generation
#
# To begin with, let's generate the observation data required for training the Neural ODE model. Toward that end, we assign a specific set of values to the ODE parameters and leverage the scipy ODE solver to simulate the corresponding dynamical system for a given timespan. This obtained time trace will serve as our training dataset.
#
# Note that here the true ODE model is used only for creating the observation data. Later, we will assume that we have no access to the complete  form of the underlying ODE, and instead train a neural network model to infer the unknown dynamics based on the observation data.

# %%
# Set parameters
r, k, h, H_max = 0.1, 1000, 0.01, 5

# Initial condition
p_0 = 20 

# Simulation time span
t_span = (0, 100)  
t_eval = np.linspace(t_span[0], t_span[1], 10000) 

# Solve ODE
solution = solve_ivp(logistic_growth, t_span, [p_0], 
                     t_eval=t_eval, args=(r, k, h, H_max))

# %% [markdown]
# Here, we visualize the general trend of the population evolution given the set ODE parameters.

# %%
plt.plot(solution.t, solution.y[0])
plt.xlabel('Time (days)')
plt.ylabel('Population Size')
plt.title('Logistic Growth Model')
plt.show()

# %% [markdown]
# #### 2.3 Data organization
#
# Next, we organize the obtained dataset into a proper format suitable for model training. There are several practical considerations worth discussing when preparing the dataset:
#
# 1. **windowing**: The entire dataset contains one time series of 100 days in real-time. Instead of overwhelming the model by feeding the entire time series, we could instead divide the full dataset into smaller chunks of continuous data samples. By processing shorter sequences at a time, we made it easier for the model to capture the complex dynamics, we greatly increased the diversity of the training data (e.g., every segment of time serie starts with a different initial condition), thus promoting the generalization capability of the model, as well as reducing the memory and computational resources for training.
#
# 2. **Overlapping**: To ensure continuity in the data, we allow adjacent windows to share a portion of data, i.e., the end of one window overlaps with the beginning of the next. This practice helps the model to maintain context across window boundaries, and effectively augment the dataset as each data point is used in multiple windows but with different contexts.
#
# 3. **Multi-Step Ahead Prediction**: To be practically useful, the model should be able to perform long-term forecasting. In practice, this is usually achieved in an autoregressive manner, i.e., the model uses its prediction at the current time step as inputs and predicts for the next time step. As a result, our training procedure should also align with such scenarios: during training, instead of using the actual observed values for each subsequent prediction step, the model uses its previous prediction as the input for the next prediction. This way improves the model's predictive accuracy and robustness for long-term forecasting tasks.

# %%
def create_windows(p_series, t_series, seq_length, overlap_length):
    """
    Create windows from the given time series data. 
    Overlapping is introduced to ensure context continuity.
    
    Inputs:
    -------
    p_series: time series of observed population size
    t_series: observed time
    seq_length: intrinsic growth rate
    overlap_length: carrying capacity
    
    Output:
    -------
    p_windows: segmented window array of population size
    t_windows: segmented window array of the time
    """
    
    p_windows, t_windows = [], []

    step_size = seq_length - overlap_length
    beg_index = 0

    while (end_idx := beg_index + seq_length) <= len(p_series):
        
        # Construct P array
        p_windows.append(p_series[beg_index:end_idx])
        
        # Calculate time intervals
        time_intervals = t_series[beg_index:end_idx] - t_series[beg_index]
        t_windows.append(time_intervals)
        
        beg_index += step_size

    return np.array(p_windows), np.array(t_windows)

# %%
# Compile dataset
p_windows, t_windows = create_windows(solution.y[0][:, np.newaxis], t_eval, seq_length=20, overlap_length=10)
print(f"p_windows array dimension: {p_windows.shape}")
# Out:
# p_windows array dimension: (999, 20, 1)

# %%
# Create TensorFlow Dataset
p_windows = p_windows.astype('float32')
t_windows = t_windows.astype('float32')

batch_size = 128
dataset = tf.data.Dataset.from_tensor_slices((p_windows, t_windows))

# %% [markdown]
# We split the entire dataset into a train set and a validation set. This validation set can be used to monitor the learning progress of the model and facilitate learning rate scheduling.
#
# Toward that end, we can randomly shuffle the dataset first and then select the first 80% for training and the remaining 20% for validation. It is worth mentioning that this way of splitting the dataset actually does not violate the temporal order: the shuffling operation only acts on the first dimension of `p_windows`, i.e., it rearranges these windows as complete units. Since each window still preserves its original temporal sequence, the overall temporal consistency of the data is not violated.

# %%
# Train/validation split
split_ratio = 0.8
train_num = int(split_ratio*len(p_windows))

# Split the dataset
dataset = dataset.shuffle(buffer_size=100000)
train_dataset = dataset.take(train_num)
val_dataset = dataset.skip(train_num)

# Batch the train & val datasets
train_dataset = train_dataset.batch(batch_size).shuffle(buffer_size=100000)
val_dataset = val_dataset.batch(batch_size)

# %% [markdown]
# ### 3. Neural ODE Solution

# %% [markdown]
# #### 3.1 Define the neural network model
#
# Here, we use a standard feed-forward neural network to represent $f_{NN}(\cdot)$. This network takes a scalar value $p(t)$ (the population size at time $t$) as input and outputs a scalar value that denotes the population change rate induced by the natural dynamics (see ODE above).
#
# To compute the final population change rate (induced by both natural dynamics and harvesting function), we define a custom layer to perform the calculation.

# %%
class PopulationChangeLayer(tf.keras.layers.Layer):
    def __init__(self, h, H_max, **kwargs):
        """
        Constructor for the custom layer for computing the population change rate.

        Inputs:
        -------
        h: harvesting rate
        H_max: maximum harvesting capacity
        """  
        super(PopulationChangeLayer, self).__init__(**kwargs)
        self.h = h
        self.H_max = H_max

    def call(self, inputs, natural_dynamcis, *args, **kwargs):
        """
        This layer takes the results of natural dynamics and adds the effect of harvesting.

        Inputs:
        -------
        inputs: population size
        natural_dynamcis: population change rate induced by natural dynamics
        """  
        
        # The governing ODE
        dp_dt = natural_dynamcis - tf.minimum(self.h*inputs, self.H_max)
        
        return dp_dt

# %%
def define_model(input_dim, hidden_dims, output_dim, init_lr, h, H_max):
    """
    Construct a standard feed-forward NN for Neural ODE.
    
    Inputs:
    -------
    input_dim: input dimension
    hidden_dims: list, dimensions for hidden layers
    output_dim: output dimension
    init_lr: initial learning rate
    h: harvesting rate
    H_max: maximum harvesting capacity
    
    Outputs:
    --------
    model: the compiled neural network model
    """    
    
    # Input layer
    input_layer = keras.layers.Input(shape=(input_dim,))

    # Hidden layers 
    for i, neuron_num in enumerate(hidden_dims):
        if i == 0:
            hidden = keras.layers.Dense(neuron_num, activation="selu", kernel_initializer='LecunNormal')(input_layer)
        
        else:
            hidden = keras.layers.Dense(neuron_num, activation="selu", kernel_initializer='LecunNormal')(hidden)
    
    # Population change rate induced by natural dynamics
    natural_dynamics = keras.layers.Dense(output_dim, activation="linear")(hidden)
    
    # Total population change rate
    dp_dt = PopulationChangeLayer(h, H_max)(input_layer, natural_dynamics)
    
    # Compile model
    model = tf.keras.models.Model(inputs=input_layer, outputs=[dp_dt, natural_dynamics])
    optimizer=tf.keras.optimizers.Adam(learning_rate=init_lr)
    model.compile(optimizer=optimizer) 
    
    return model

# %% [markdown]
# #### 3.2 Define loss function
#
# Here, we define a custom loss function to facilitate neural ODE training. Specifically, we implement the logic of multi-step ahead prediction to improve the model's accuracy and robustness for performing long-term forecasting.

# %%
@tf.function
def train_step(p_batch, t_batch, ode_nn):
    """Calculate loss and its gradients with respect to network model parameters.
    
    Inputs:
    ----
    p_batch: a batch of population evolution data, [batch_size, timesteps, feature_dim]
    t_batch: a batch of time evolution data, [batch_size, timesteps, feature_dim]
    ode_nn: neural ODE model 
    
    Outputs:
    --------
    ODE_loss: calculated ODE loss
    gradients: gradients of the ODE loss with respect to network model parameters.
    """
    
    with tf.GradientTape() as tape:
        batch_size, seq_length, _ = p_batch.shape
        loss = 0

        # Batch processing each step of the time series
        p = p_batch[:, 0]
        for i in range(seq_length - 1):
            
            # Calculate time step
            delta_t = t_batch[:, i+1] - t_batch[:, i]

            # Calculate the population change rate
            dp_dt, _ = ode_nn(p)

            # Euler scheme  
            p = p + delta_t[:, tf.newaxis]*dp_dt

            # Sum loss for the whole batch (for the current time step)
            loss += tf.reduce_mean(tf.square(p - p_batch[:, i+1]))

        # Average the loss over all time steps
        loss /= (seq_length - 1)

    # Compute gradients
    gradients = tape.gradient(loss, ode_nn.trainable_variables)

    return loss, gradients

# %%
def val_step(p_batch, t_batch, ode_nn):
    """Calculate validation loss.
    
    Inputs:
    ----
    p_batch: a batch of population evolution data, [batch_size, timesteps, feature_dim]
    t_batch: a batch of time evolution data, [batch_size, timesteps, feature_dim]
    ode_nn: neural ODE model 
    
    Outputs:
    --------
    loss: calculated ODE loss
    """
    batch_size, seq_length, _ = p_batch.shape
    loss = 0

    # Batch processing each step of the time series
    p = p_batch[:, 0]
    for i in range(seq_length - 1):

        # Calculate time step
        delta_t = t_batch[:, i+1] - t_batch[:, i]

        # Calculate the population change rate
        dp_dt, _ = ode_nn(p)

        # Euler scheme  
        p = p + delta_t[:, tf.newaxis]*dp_dt

        # Sum loss for the whole batch (for the current time step)
        loss += tf.reduce_mean(tf.square(p - p_batch[:, i+1]))

    # Average the loss over all time steps
    loss /= (seq_length - 1)

    return loss

# %% [markdown]
# #### 3.3 Training logic

# %%
# Setup NN hyperparameters
input_dim, output_dim = 1, 1
hidden_dims = [5, 5, 5]

# Instantiate NN
ode_nn = define_model(input_dim, hidden_dims, output_dim, init_lr=1e-2, h=h, H_max=H_max)

# Training Loop
num_epochs = 600
train_loss_hist, val_loss_hist = [], []

with tf.device("CPU:0"):
    
    # Configure learning rate scheduler
    ode_nn_callbacks = tf.keras.callbacks.CallbackList(
                      [keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=50)], 
                        add_history=False, model=ode_nn)

    for epoch in range(num_epochs):
        
        # Initialize epoch-wise losses
        train_total_loss, val_total_loss = 0, 0

        # Training
        for p_batch, t_batch in train_dataset:
            
            # Calculate loss & gradients
            train_loss, gradients = train_step(p_batch, t_batch, ode_nn)
            
            # Update parameters
            ode_nn.optimizer.apply_gradients(zip(gradients, ode_nn.trainable_variables))
            
            # Accumulate loss
            train_total_loss += train_loss

        # Normalize loss
        train_total_loss /= len(train_dataset)

        # Validation loop
        for p_batch, t_batch in val_dataset:
            val_loss = val_step(p_batch, t_batch, ode_nn)
            val_total_loss += val_loss

        # Normalize validation loss
        val_total_loss /= len(val_dataset)

        # Callbacks
        ode_nn_callbacks.on_epoch_end(epoch, logs={'val_loss': val_total_loss})

        # Logging
        print(f"Epoch {epoch+1}:")
        print(f"Train Loss: {train_total_loss.numpy():.3e}, Val Loss: {val_total_loss.numpy():.3e}")
        print(f"lr: {ode_nn.optimizer.lr.numpy():.3e}")

        train_loss_hist.append(train_total_loss)
        val_loss_hist.append(val_total_loss)
        
        # Reshuffle train dataset
        dataset = dataset.shuffle(buffer_size=100000)
        train_dataset = dataset.take(train_num).shuffle(buffer_size=100000).batch(batch_size)
        val_dataset = dataset.skip(train_num).batch(batch_size)
# Out:
# Epoch 1:
# Train Loss: 4.398e+01, Val Loss: 9.158e+00
# lr: 1.000e-02
# Epoch 2:
# Train Loss: 3.754e+00, Val Loss: 1.503e+00
# lr: 1.000e-02
# Epoch 3:
# Train Loss: 2.337e+00, Val Loss: 2.969e+00
# lr: 1.000e-02
# Epoch 4:
# Train Loss: 2.202e+00, Val Loss: 1.101e+00
# lr: 1.000e-02
# Epoch 5:
# Train Loss: 1.255e+00, Val Loss: 1.240e+00
# lr: 1.000e-02
# Epoch 6:
# Train Loss: 1.084e+00, Val Loss: 9.613e-01
# lr: 1.000e-02
# Epoch 7:
# Train Loss: 9.841e-01, Val Loss: 9.940e-01
# lr: 1.000e-02
# Epoch 8:
# Train Loss: 9.761e-01, Val Loss: 1.005e+00
# lr: 1.000e-02
# Epoch 9:
# Train Loss: 8.989e-01, Val Loss: 9.487e-01
# lr: 1.000e-02
# Epoch 10:
# Train Loss: 8.723e-01, Val Loss: 9.164e-01
# lr: 1.000e-02
# Epoch 11:
# Train Loss: 8.752e-01, Val Loss: 9.411e-01
# lr: 1.000e-02
# Epoch 12:
# Train Loss: 7.928e-01, Val Loss: 7.637e-01
# lr: 1.000e-02
# Epoch 13:
# Train Loss: 7.555e-01, Val Loss: 7.928e-01
# lr: 1.000e-02
# Epoch 14:
# Train Loss: 6.994e-01, Val Loss: 6.379e-01
# lr: 1.000e-02
# Epoch 15:
# Train Loss: 7.323e-01, Val Loss: 6.663e-01
# lr: 1.000e-02
# Epoch 16:
# Train Loss: 6.856e-01, Val Loss: 6.640e-01
# lr: 1.000e-02
# Epoch 17:
# Train Loss: 5.944e-01, Val Loss: 6.028e-01
# lr: 1.000e-02
# Epoch 18:
# Train Loss: 6.698e-01, Val Loss: 5.114e-01
# lr: 1.000e-02
# Epoch 19:
# Train Loss: 5.488e-01, Val Loss: 5.553e-01
# lr: 1.000e-02
# Epoch 20:
# Train Loss: 5.119e-01, Val Loss: 5.157e-01
# lr: 1.000e-02
# Epoch 21:
# Train Loss: 4.517e-01, Val Loss: 3.651e-01
# lr: 1.000e-02
# Epoch 22:
# Train Loss: 3.971e-01, Val Loss: 3.390e-01
# lr: 5.000e-03
# Epoch 239:
# Train Loss: 1.616e-03, Val Loss: 2.233e-03
# lr: 5.000e-03
# Epoch 240:
# Train Loss: 1.780e-03, Val Loss: 1.699e-03
# lr: 5.000e-03
# Epoch 241:
# Train Loss: 1.692e-03, Val Loss: 1.652e-03
# lr: 5.000e-03
# Epoch 242:
# Train Loss: 1.452e-03, Val Loss: 1.664e-03
# lr: 5.000e-03
# Epoch 243:
# Train Loss: 1.438e-03, Val Loss: 1.286e-03
# lr: 5.000e-03
# Epoch 244:
# Train Loss: 1.316e-03, Val Loss: 1.334e-03
# lr: 5.000e-03
# Epoch 245:
# Train Loss: 1.412e-03, Val Loss: 1.654e-03
# lr: 5.000e-03
# Epoch 246:
# Train Loss: 1.387e-03, Val Loss: 1.165e-03
# lr: 5.000e-03
# Epoch 247:
# Train Loss: 1.242e-03, Val Loss: 1.183e-03
# lr: 5.000e-03
# Epoch 248:
# Train Loss: 1.129e-03, Val Loss: 1.658e-03
# lr: 5.000e-03
# Epoch 249:
# Train Loss: 1.327e-03, Val Loss: 1.052e-03
# lr: 5.000e-03
# Epoch 250:
# Train Loss: 1.147e-03, Val Loss: 1.341e-03
# lr: 5.000e-03
# Epoch 251:
# Train Loss: 1.189e-03, Val Loss: 1.151e-03
# lr: 5.000e-03
# Epoch 252:
# Train Loss: 1.036e-03, Val Loss: 1.010e-03
# lr: 5.000e-03
# Epoch 253:
# Train Loss: 9.417e-04, Val Loss: 9.685e-04
# lr: 5.000e-03
# Epoch 254:
# Train Loss: 8.808e-04, Val Loss: 8.992e-04
# lr: 5.000e-03
# Epoch 255:
# Train Loss: 9.707e-04, Val Loss: 1.079e-03
# lr: 5.000e-03
# Epoch 256:
# Train Loss: 1.091e-03, Val Loss: 8.948e-04
# lr: 5.000e-03
# Epoch 257:
# Train Loss: 1.038e-03, Val Loss: 1.084e-03
# lr: 5.000e-03
# Epoch 258:
# Train Loss: 1.014e-03, Val Loss: 9.318e-04
# lr: 5.000e-03
# Epoch 259:
# Train Loss: 8.849e-04, Val Loss: 9.288e-04
# lr: 5.000e-03
# Epoch 260:
# Train Loss: 8.693e-04, Val Loss: 7.641e-04
# lr: 5.000e-03
# Epoch 261:
# Train Loss: 8.313e-04, Val Loss: 8.574e-04
# lr: 5.000e-03
# Epoch 262:
# Train Loss: 8.354e-04, Val Loss: 8.758e-04
# lr: 5.000e-03
# Epoch 263:
# Train Loss: 8.455e-04, Val Loss: 7.357e-04
# lr: 5.000e-03
# Epoch 264:
# Train Loss: 8.112e-04, Val Loss: 7.489e-04
# lr: 5.000e-03
# Epoch 265:
# Train Loss: 7.900e-04, Val Loss: 1.080e-03
# lr: 5.000e-03
# Epoch 266:
# Train Loss: 8.566e-04, Val Loss: 1.114e-03
# lr: 5.000e-03
# Epoch 267:
# Train Loss: 9.691e-04, Val Loss: 1.897e-03
# lr: 5.000e-03
# Epoch 268:
# Train Loss: 1.487e-03, Val Loss: 8.597e-04
# lr: 5.000e-03
# Epoch 269:
# Train Loss: 1.217e-03, Val Loss: 1.329e-03
# lr: 5.000e-03
# Epoch 270:
# Train Loss: 1.261e-03, Val Loss: 9.174e-04
# lr: 5.000e-03
# Epoch 271:
# Train Loss: 9.587e-04, Val Loss: 8.186e-04
# lr: 5.000e-03
# Epoch 272:
# Train Loss: 7.865e-04, Val Loss: 8.292e-04
# lr: 5.000e-03
# Epoch 273:
# Train Loss: 9.121e-04, Val Loss: 6.722e-04
# lr: 5.000e-03
# Epoch 274:
# Train Loss: 6.902e-04, Val Loss: 1.073e-03
# lr: 5.000e-03
# Epoch 275:
# Train Loss: 8.495e-04, Val Loss: 5.841e-04
# lr: 5.000e-03
# Epoch 276:
# Train Loss: 7.210e-04, Val Loss: 8.041e-04
# lr: 5.000e-03
# Epoch 277:
# Train Loss: 7.423e-04, Val Loss: 7.333e-04
# lr: 5.000e-03
# Epoch 278:
# Train Loss: 8.327e-04, Val Loss: 1.081e-03
# lr: 5.000e-03
# Epoch 279:
# Train Loss: 8.148e-04, Val Loss: 7.388e-04
# lr: 5.000e-03
# Epoch 280:
# Train Loss: 7.237e-04, Val Loss: 6.195e-04
# lr: 5.000e-03
# Epoch 281:
# Train Loss: 6.607e-04, Val Loss: 5.122e-04
# lr: 5.000e-03
# Epoch 282:
# Train Loss: 6.523e-04, Val Loss: 6.006e-04
# lr: 5.000e-03
# Epoch 283:
# Train Loss: 6.662e-04, Val Loss: 5.939e-04
# lr: 5.000e-03
# Epoch 284:
# Train Loss: 6.243e-04, Val Loss: 7.079e-04
# lr: 5.000e-03
# Epoch 285:
# Train Loss: 6.479e-04, Val Loss: 5.268e-04
# lr: 5.000e-03
# Epoch 286:
# Train Loss: 6.342e-04, Val Loss: 7.418e-04
# lr: 5.000e-03
# Epoch 287:
# Train Loss: 6.494e-04, Val Loss: 5.844e-04
# lr: 5.000e-03
# Epoch 288:
# Train Loss: 5.826e-04, Val Loss: 6.027e-04
# lr: 5.000e-03
# Epoch 289:
# Train Loss: 6.517e-04, Val Loss: 6.430e-04
# lr: 5.000e-03
# Epoch 290:
# Train Loss: 5.945e-04, Val Loss: 4.817e-04
# lr: 5.000e-03
# Epoch 291:
# Train Loss: 5.227e-04, Val Loss: 6.415e-04
# lr: 5.000e-03
# Epoch 292:
# Train Loss: 6.396e-04, Val Loss: 6.465e-04
# lr: 5.000e-03
# Epoch 293:
# Train Loss: 9.215e-04, Val Loss: 1.031e-03
# lr: 5.000e-03
# Epoch 294:
# Train Loss: 8.764e-04, Val Loss: 6.704e-04
# lr: 5.000e-03
# Epoch 295:
# Train Loss: 6.303e-04, Val Loss: 5.115e-04
# lr: 5.000e-03
# Epoch 296:
# Train Loss: 5.191e-04, Val Loss: 4.842e-04
# lr: 5.000e-03
# Epoch 297:
# Train Loss: 5.652e-04, Val Loss: 5.051e-04
# lr: 5.000e-03
# Epoch 298:
# Train Loss: 5.738e-04, Val Loss: 6.407e-04
# lr: 5.000e-03
# Epoch 299:
# Train Loss: 7.161e-04, Val Loss: 7.517e-04
# lr: 5.000e-03
# Epoch 300:
# Train Loss: 6.901e-04, Val Loss: 7.728e-04
# lr: 5.000e-03
# Epoch 301:
# Train Loss: 7.084e-04, Val Loss: 7.345e-04
# lr: 5.000e-03
# Epoch 302:
# Train Loss: 7.407e-04, Val Loss: 5.371e-04
# lr: 5.000e-03
# Epoch 303:
# Train Loss: 6.866e-04, Val Loss: 7.750e-04
# lr: 5.000e-03
# Epoch 304:
# Train Loss: 8.124e-04, Val Loss: 5.941e-04
# lr: 5.000e-03
# Epoch 305:
# Train Loss: 5.476e-04, Val Loss: 9.722e-04
# lr: 5.000e-03
# Epoch 306:
# Train Loss: 8.316e-04, Val Loss: 5.454e-04
# lr: 5.000e-03
# Epoch 307:
# Train Loss: 4.702e-04, Val Loss: 5.474e-04
# lr: 5.000e-03
# Epoch 308:
# Train Loss: 5.579e-04, Val Loss: 5.197e-04
# lr: 5.000e-03
# Epoch 309:
# Train Loss: 5.229e-04, Val Loss: 7.489e-04
# lr: 5.000e-03
# Epoch 310:
# Train Loss: 6.360e-04, Val Loss: 5.667e-04
# lr: 5.000e-03
# Epoch 311:
# Train Loss: 5.173e-04, Val Loss: 6.541e-04
# lr: 5.000e-03
# Epoch 312:
# Train Loss: 5.822e-04, Val Loss: 5.500e-04
# lr: 5.000e-03
# Epoch 313:
# Train Loss: 4.938e-04, Val Loss: 6.024e-04
# lr: 5.000e-03
# Epoch 314:
# Train Loss: 4.956e-04, Val Loss: 5.144e-04
# lr: 5.000e-03
# Epoch 315:
# Train Loss: 5.171e-04, Val Loss: 1.449e-03
# lr: 5.000e-03
# Epoch 316:
# Train Loss: 8.111e-04, Val Loss: 8.562e-04
# lr: 5.000e-03
# Epoch 317:
# Train Loss: 6.926e-04, Val Loss: 5.752e-04
# lr: 5.000e-03
# Epoch 318:
# Train Loss: 5.154e-04, Val Loss: 6.618e-04
# lr: 5.000e-03
# Epoch 319:
# Train Loss: 5.874e-04, Val Loss: 8.307e-04
# lr: 5.000e-03
# Epoch 320:
# Train Loss: 5.821e-04, Val Loss: 5.422e-04
# lr: 5.000e-03
# Epoch 321:
# Train Loss: 5.285e-04, Val Loss: 6.988e-04
# lr: 5.000e-03
# Epoch 322:
# Train Loss: 7.632e-04, Val Loss: 7.403e-04
# lr: 5.000e-03
# Epoch 323:
# Train Loss: 6.656e-04, Val Loss: 4.259e-04
# lr: 5.000e-03
# Epoch 324:
# Train Loss: 4.846e-04, Val Loss: 5.554e-04
# lr: 5.000e-03
# Epoch 325:
# Train Loss: 5.715e-04, Val Loss: 3.980e-04
# lr: 5.000e-03
# Epoch 326:
# Train Loss: 4.638e-04, Val Loss: 4.189e-04
# lr: 5.000e-03
# Epoch 327:
# Train Loss: 4.864e-04, Val Loss: 5.352e-04
# lr: 5.000e-03
# Epoch 328:
# Train Loss: 6.566e-04, Val Loss: 7.130e-04
# lr: 5.000e-03
# Epoch 329:
# Train Loss: 9.186e-04, Val Loss: 5.199e-04
# lr: 5.000e-03
# Epoch 330:
# Train Loss: 6.436e-04, Val Loss: 3.920e-04
# lr: 5.000e-03
# Epoch 331:
# Train Loss: 5.208e-04, Val Loss: 4.251e-04
# lr: 5.000e-03
# Epoch 332:
# Train Loss: 6.007e-04, Val Loss: 5.775e-04
# lr: 5.000e-03
# Epoch 333:
# Train Loss: 5.187e-04, Val Loss: 6.169e-04
# lr: 5.000e-03
# Epoch 334:
# Train Loss: 7.003e-04, Val Loss: 4.069e-04
# lr: 5.000e-03
# Epoch 335:
# Train Loss: 5.349e-04, Val Loss: 4.858e-04
# lr: 5.000e-03
# Epoch 336:
# Train Loss: 4.539e-04, Val Loss: 5.909e-04
# lr: 5.000e-03
# Epoch 337:
# Train Loss: 5.063e-04, Val Loss: 6.081e-04
# lr: 5.000e-03
# Epoch 338:
# Train Loss: 6.102e-04, Val Loss: 5.108e-04
# lr: 5.000e-03
# Epoch 339:
# Train Loss: 4.672e-04, Val Loss: 4.245e-04
# lr: 5.000e-03
# Epoch 340:
# Train Loss: 4.306e-04, Val Loss: 3.983e-04
# lr: 2.500e-03
# Epoch 341:
# Train Loss: 4.315e-04, Val Loss: 4.058e-04
# lr: 2.500e-03
# Epoch 342:
# Train Loss: 4.073e-04, Val Loss: 4.057e-04
# lr: 2.500e-03
# Epoch 343:
# Train Loss: 4.098e-04, Val Loss: 4.098e-04
# lr: 2.500e-03
# Epoch 344:
# Train Loss: 3.800e-04, Val Loss: 4.688e-04
# lr: 2.500e-03
# Epoch 345:
# Train Loss: 4.082e-04, Val Loss: 3.532e-04
# lr: 2.500e-03
# Epoch 346:
# Train Loss: 3.929e-04, Val Loss: 3.831e-04
# lr: 2.500e-03
# Epoch 347:
# Train Loss: 4.016e-04, Val Loss: 4.331e-04
# lr: 2.500e-03
# Epoch 348:
# Train Loss: 3.840e-04, Val Loss: 3.813e-04
# lr: 2.500e-03
# Epoch 349:
# Train Loss: 3.866e-04, Val Loss: 4.101e-04
# lr: 2.500e-03
# Epoch 350:
# Train Loss: 3.954e-04, Val Loss: 3.890e-04
# lr: 2.500e-03
# Epoch 351:
# Train Loss: 4.154e-04, Val Loss: 3.333e-04
# lr: 2.500e-03
# Epoch 352:
# Train Loss: 4.214e-04, Val Loss: 4.107e-04
# lr: 2.500e-03
# Epoch 353:
# Train Loss: 4.274e-04, Val Loss: 4.133e-04
# lr: 2.500e-03
# Epoch 354:
# Train Loss: 4.051e-04, Val Loss: 4.094e-04
# lr: 2.500e-03
# Epoch 355:
# Train Loss: 3.989e-04, Val Loss: 3.387e-04
# lr: 2.500e-03
# Epoch 356:
# Train Loss: 3.663e-04, Val Loss: 3.906e-04
# lr: 2.500e-03
# Epoch 357:
# Train Loss: 3.999e-04, Val Loss: 4.397e-04
# lr: 2.500e-03
# Epoch 358:
# Train Loss: 3.818e-04, Val Loss: 4.298e-04
# lr: 2.500e-03
# Epoch 359:
# Train Loss: 3.895e-04, Val Loss: 4.703e-04
# lr: 2.500e-03
# Epoch 360:
# Train Loss: 4.053e-04, Val Loss: 4.211e-04
# lr: 2.500e-03
# Epoch 361:
# Train Loss: 3.920e-04, Val Loss: 3.255e-04
# lr: 2.500e-03
# Epoch 362:
# Train Loss: 3.392e-04, Val Loss: 4.579e-04
# lr: 2.500e-03
# Epoch 363:
# Train Loss: 4.164e-04, Val Loss: 3.980e-04
# lr: 2.500e-03
# Epoch 364:
# Train Loss: 3.816e-04, Val Loss: 3.784e-04
# lr: 2.500e-03
# Epoch 365:
# Train Loss: 3.698e-04, Val Loss: 3.473e-04
# lr: 2.500e-03
# Epoch 366:
# Train Loss: 3.870e-04, Val Loss: 4.278e-04
# lr: 2.500e-03
# Epoch 367:
# Train Loss: 3.847e-04, Val Loss: 3.707e-04
# lr: 2.500e-03
# Epoch 368:
# Train Loss: 3.798e-04, Val Loss: 4.526e-04
# lr: 2.500e-03
# Epoch 369:
# Train Loss: 3.869e-04, Val Loss: 4.442e-04
# lr: 2.500e-03
# Epoch 370:
# Train Loss: 3.755e-04, Val Loss: 3.851e-04
# lr: 2.500e-03
# Epoch 371:
# Train Loss: 3.780e-04, Val Loss: 3.482e-04
# lr: 2.500e-03
# Epoch 372:
# Train Loss: 3.817e-04, Val Loss: 3.234e-04
# lr: 2.500e-03
# Epoch 373:
# Train Loss: 3.696e-04, Val Loss: 3.582e-04
# lr: 2.500e-03
# Epoch 374:
# Train Loss: 3.956e-04, Val Loss: 4.410e-04
# lr: 2.500e-03
# Epoch 375:
# Train Loss: 3.707e-04, Val Loss: 3.490e-04
# lr: 2.500e-03
# Epoch 376:
# Train Loss: 3.982e-04, Val Loss: 5.504e-04
# lr: 2.500e-03
# Epoch 377:
# Train Loss: 4.852e-04, Val Loss: 4.500e-04
# lr: 2.500e-03
# Epoch 378:
# Train Loss: 3.783e-04, Val Loss: 3.308e-04
# lr: 2.500e-03
# Epoch 379:
# Train Loss: 3.548e-04, Val Loss: 4.029e-04
# lr: 2.500e-03
# Epoch 380:
# Train Loss: 3.450e-04, Val Loss: 3.542e-04
# lr: 2.500e-03
# Epoch 381:
# Train Loss: 3.531e-04, Val Loss: 3.377e-04
# lr: 2.500e-03
# Epoch 382:
# Train Loss: 3.720e-04, Val Loss: 3.529e-04
# lr: 2.500e-03
# Epoch 383:
# Train Loss: 3.323e-04, Val Loss: 3.353e-04
# lr: 2.500e-03
# Epoch 384:
# Train Loss: 3.502e-04, Val Loss: 2.749e-04
# lr: 2.500e-03
# Epoch 385:
# Train Loss: 3.585e-04, Val Loss: 3.547e-04
# lr: 2.500e-03
# Epoch 386:
# Train Loss: 3.690e-04, Val Loss: 4.957e-04
# lr: 2.500e-03
# Epoch 387:
# Train Loss: 4.022e-04, Val Loss: 3.255e-04
# lr: 2.500e-03
# Epoch 388:
# Train Loss: 4.023e-04, Val Loss: 4.412e-04
# lr: 2.500e-03
# Epoch 389:
# Train Loss: 4.563e-04, Val Loss: 5.117e-04
# lr: 2.500e-03
# Epoch 390:
# Train Loss: 4.059e-04, Val Loss: 3.998e-04
# lr: 2.500e-03
# Epoch 391:
# Train Loss: 3.637e-04, Val Loss: 3.405e-04
# lr: 2.500e-03
# Epoch 392:
# Train Loss: 3.606e-04, Val Loss: 4.395e-04
# lr: 1.250e-03
# Epoch 424:
# Train Loss: 3.126e-04, Val Loss: 3.108e-04
# lr: 1.250e-03
# Epoch 425:
# Train Loss: 3.089e-04, Val Loss: 2.670e-04
# lr: 1.250e-03
# Epoch 426:
# Train Loss: 3.224e-04, Val Loss: 3.333e-04
# lr: 1.250e-03
# Epoch 427:
# Train Loss: 3.303e-04, Val Loss: 2.822e-04
# lr: 1.250e-03
# Epoch 428:
# Train Loss: 3.348e-04, Val Loss: 3.136e-04
# lr: 1.250e-03
# Epoch 429:
# Train Loss: 3.036e-04, Val Loss: 3.615e-04
# lr: 1.250e-03
# Epoch 430:
# Train Loss: 3.492e-04, Val Loss: 3.526e-04
# lr: 1.250e-03
# Epoch 431:
# Train Loss: 3.306e-04, Val Loss: 4.027e-04
# lr: 1.250e-03
# Epoch 432:
# Train Loss: 3.466e-04, Val Loss: 3.564e-04
# lr: 1.250e-03
# Epoch 433:
# Train Loss: 3.256e-04, Val Loss: 3.284e-04
# lr: 1.250e-03
# Epoch 434:
# Train Loss: 3.567e-04, Val Loss: 4.352e-04
# lr: 1.250e-03
# Epoch 435:
# Train Loss: 3.394e-04, Val Loss: 3.908e-04
# lr: 1.250e-03
# Epoch 436:
# Train Loss: 3.246e-04, Val Loss: 2.842e-04
# lr: 1.250e-03
# Epoch 437:
# Train Loss: 3.174e-04, Val Loss: 2.935e-04
# lr: 1.250e-03
# Epoch 438:
# Train Loss: 3.196e-04, Val Loss: 3.255e-04
# lr: 1.250e-03
# Epoch 439:
# Train Loss: 3.170e-04, Val Loss: 2.976e-04
# lr: 1.250e-03
# Epoch 440:
# Train Loss: 3.463e-04, Val Loss: 3.759e-04
# lr: 1.250e-03
# Epoch 441:
# Train Loss: 3.258e-04, Val Loss: 3.183e-04
# lr: 1.250e-03
# Epoch 442:
# Train Loss: 2.971e-04, Val Loss: 3.237e-04
# lr: 1.250e-03
# Epoch 443:
# Train Loss: 3.035e-04, Val Loss: 3.480e-04
# lr: 1.250e-03
# Epoch 444:
# Train Loss: 3.236e-04, Val Loss: 3.555e-04
# lr: 1.250e-03
# Epoch 445:
# Train Loss: 2.887e-04, Val Loss: 3.362e-04
# lr: 6.250e-04
# Epoch 446:
# Train Loss: 3.232e-04, Val Loss: 2.764e-04
# lr: 6.250e-04
# Epoch 447:
# Train Loss: 3.139e-04, Val Loss: 3.015e-04
# lr: 6.250e-04
# Epoch 448:
# Train Loss: 3.234e-04, Val Loss: 2.875e-04
# lr: 6.250e-04
# Epoch 449:
# Train Loss: 3.137e-04, Val Loss: 3.300e-04
# lr: 6.250e-04
# Epoch 450:
# Train Loss: 2.914e-04, Val Loss: 3.123e-04
# lr: 6.250e-04
# Epoch 451:
# Train Loss: 3.342e-04, Val Loss: 3.130e-04
# lr: 6.250e-04
# Epoch 452:
# Train Loss: 3.108e-04, Val Loss: 3.313e-04
# lr: 6.250e-04
# Epoch 453:
# Train Loss: 3.171e-04, Val Loss: 2.914e-04
# lr: 6.250e-04
# Epoch 454:
# Train Loss: 3.077e-04, Val Loss: 3.538e-04
# Train Loss: 3.076e-04, Val Loss: 2.983e-04
# lr: 6.250e-04
# Epoch 517:
# Train Loss: 3.143e-04, Val Loss: 3.068e-04
# lr: 3.125e-04
# Epoch 518:
# Train Loss: 3.249e-04, Val Loss: 2.739e-04
# lr: 3.125e-04
# Epoch 519:
# Train Loss: 3.261e-04, Val Loss: 2.574e-04
# lr: 3.125e-04
# Epoch 520:
# Train Loss: 2.722e-04, Val Loss: 2.931e-04
# lr: 3.125e-04
# Epoch 521:
# Train Loss: 3.092e-04, Val Loss: 2.583e-04
# lr: 3.125e-04
# Epoch 522:
# Train Loss: 2.944e-04, Val Loss: 2.997e-04
# lr: 3.125e-04
# Epoch 523:
# Train Loss: 2.879e-04, Val Loss: 3.357e-04
# lr: 3.125e-04
# Epoch 524:
# Train Loss: 2.808e-04, Val Loss: 3.732e-04
# lr: 3.125e-04
# Epoch 525:
# Train Loss: 2.789e-04, Val Loss: 2.402e-04
# lr: 3.125e-04
# Epoch 526:
# Train Loss: 2.949e-04, Val Loss: 2.993e-04
# lr: 3.125e-04
# Epoch 527:
# Train Loss: 2.797e-04, Val Loss: 2.739e-04
# lr: 3.125e-04
# Epoch 528:
# Train Loss: 2.839e-04, Val Loss: 2.329e-04
# lr: 3.125e-04
# Epoch 529:
# Train Loss: 2.974e-04, Val Loss: 3.016e-04
# lr: 3.125e-04
# Epoch 530:
# Train Loss: 2.849e-04, Val Loss: 3.699e-04
# lr: 3.125e-04
# Epoch 531:
# Train Loss: 3.198e-04, Val Loss: 3.012e-04
# lr: 3.125e-04
# Epoch 532:
# Train Loss: 2.950e-04, Val Loss: 3.412e-04
# lr: 3.125e-04
# Epoch 533:
# Train Loss: 3.147e-04, Val Loss: 2.774e-04
# lr: 3.125e-04
# Epoch 534:
# Train Loss: 2.970e-04, Val Loss: 2.781e-04
# lr: 3.125e-04
# Epoch 535:
# Train Loss: 3.097e-04, Val Loss: 3.126e-04
# lr: 3.125e-04
# Epoch 536:
# Train Loss: 3.193e-04, Val Loss: 2.843e-04
# lr: 3.125e-04
# Epoch 537:
# Train Loss: 2.991e-04, Val Loss: 3.046e-04
# lr: 3.125e-04
# Epoch 538:
# Train Loss: 2.887e-04, Val Loss: 2.965e-04
# lr: 3.125e-04
# Epoch 539:
# Train Loss: 2.897e-04, Val Loss: 2.827e-04
# lr: 3.125e-04
# Epoch 540:
# Train Loss: 2.913e-04, Val Loss: 2.789e-04
# lr: 3.125e-04
# Epoch 541:
# Train Loss: 2.928e-04, Val Loss: 2.462e-04
# lr: 3.125e-04
# Epoch 542:
# Train Loss: 2.891e-04, Val Loss: 2.899e-04
# lr: 3.125e-04
# Epoch 543:
# Train Loss: 2.998e-04, Val Loss: 3.205e-04
# lr: 3.125e-04
# Epoch 544:
# Train Loss: 3.085e-04, Val Loss: 2.886e-04
# lr: 3.125e-04
# Epoch 545:
# Train Loss: 3.014e-04, Val Loss: 2.961e-04
# lr: 3.125e-04
# Epoch 546:
# Train Loss: 2.841e-04, Val Loss: 3.193e-04
# lr: 3.125e-04
# Epoch 547:
# Train Loss: 2.988e-04, Val Loss: 2.733e-04
# lr: 3.125e-04
# Epoch 548:
# Train Loss: 2.808e-04, Val Loss: 2.780e-04
# lr: 3.125e-04
# Epoch 549:
# Train Loss: 2.889e-04, Val Loss: 3.084e-04
# lr: 3.125e-04
# Epoch 550:
# Train Loss: 3.213e-04, Val Loss: 2.740e-04
# lr: 3.125e-04
# Epoch 551:
# Train Loss: 2.998e-04, Val Loss: 2.681e-04
# lr: 3.125e-04
# Epoch 552:
# Train Loss: 2.950e-04, Val Loss: 3.117e-04
# lr: 3.125e-04
# Epoch 553:
# Train Loss: 2.916e-04, Val Loss: 3.229e-04
# lr: 3.125e-04
# Epoch 554:
# Train Loss: 2.939e-04, Val Loss: 3.064e-04
# lr: 3.125e-04
# Epoch 555:
# Train Loss: 2.772e-04, Val Loss: 2.938e-04
# lr: 3.125e-04
# Epoch 556:
# Train Loss: 2.784e-04, Val Loss: 2.771e-04
# lr: 3.125e-04
# Epoch 557:
# Train Loss: 3.202e-04, Val Loss: 2.835e-04
# lr: 3.125e-04
# Epoch 558:
# Train Loss: 2.911e-04, Val Loss: 2.590e-04
# lr: 3.125e-04
# Epoch 559:
# Train Loss: 2.950e-04, Val Loss: 2.807e-04
# lr: 3.125e-04
# Epoch 560:
# Train Loss: 2.895e-04, Val Loss: 3.200e-04
# lr: 3.125e-04
# Epoch 561:
# Train Loss: 3.071e-04, Val Loss: 3.381e-04
# lr: 3.125e-04
# Epoch 562:
# Train Loss: 2.779e-04, Val Loss: 2.995e-04
# lr: 3.125e-04
# Epoch 563:
# Train Loss: 2.830e-04, Val Loss: 3.363e-04
# lr: 3.125e-04
# Epoch 564:
# Train Loss: 2.990e-04, Val Loss: 2.892e-04
# lr: 3.125e-04
# Epoch 565:
# Train Loss: 2.974e-04, Val Loss: 2.713e-04
# lr: 3.125e-04
# Epoch 566:
# Train Loss: 3.007e-04, Val Loss: 2.828e-04
# lr: 3.125e-04
# Epoch 567:
# Train Loss: 2.897e-04, Val Loss: 3.067e-04
# lr: 1.562e-04
# Epoch 568:
# Train Loss: 2.914e-04, Val Loss: 2.661e-04
# lr: 1.562e-04
# Epoch 569:
# Train Loss: 3.043e-04, Val Loss: 3.987e-04
# lr: 1.562e-04
# Epoch 570:
# Train Loss: 2.830e-04, Val Loss: 2.856e-04
# lr: 1.562e-04
# Epoch 571:
# Train Loss: 2.775e-04, Val Loss: 3.212e-04
# lr: 1.562e-04
# Epoch 572:
# Train Loss: 2.871e-04, Val Loss: 2.590e-04
# lr: 1.562e-04
# Epoch 573:
# Train Loss: 2.868e-04, Val Loss: 2.656e-04
# lr: 1.562e-04
# Epoch 574:
# Train Loss: 2.895e-04, Val Loss: 3.560e-04
# lr: 1.562e-04
# Epoch 575:
# Train Loss: 2.799e-04, Val Loss: 3.015e-04
# lr: 1.562e-04
# Epoch 576:
# Train Loss: 2.905e-04, Val Loss: 2.829e-04
# lr: 1.562e-04
# Epoch 577:
# Train Loss: 2.788e-04, Val Loss: 2.709e-04
# lr: 1.562e-04
# Epoch 578:
# Train Loss: 2.891e-04, Val Loss: 3.088e-04
# lr: 1.562e-04
# Epoch 579:
# Train Loss: 2.761e-04, Val Loss: 3.046e-04
# lr: 1.562e-04
# Epoch 580:
# Train Loss: 3.071e-04, Val Loss: 3.369e-04
# lr: 1.562e-04
# Epoch 581:
# Train Loss: 2.848e-04, Val Loss: 3.457e-04
# lr: 1.562e-04
# Epoch 582:
# Train Loss: 2.938e-04, Val Loss: 3.100e-04
# lr: 1.562e-04
# Epoch 583:
# Train Loss: 2.896e-04, Val Loss: 2.501e-04
# lr: 1.562e-04
# Epoch 584:
# Train Loss: 2.957e-04, Val Loss: 2.687e-04
# lr: 1.562e-04
# Epoch 585:
# Train Loss: 2.987e-04, Val Loss: 3.057e-04
# lr: 1.562e-04
# Epoch 586:
# Train Loss: 2.885e-04, Val Loss: 2.829e-04
# lr: 1.562e-04
# Epoch 587:
# Train Loss: 2.851e-04, Val Loss: 3.388e-04
# lr: 1.562e-04
# Epoch 588:
# Train Loss: 2.899e-04, Val Loss: 3.066e-04
# lr: 1.562e-04
# Epoch 589:
# Train Loss: 2.942e-04, Val Loss: 2.918e-04
# lr: 1.562e-04
# Epoch 590:
# Train Loss: 2.829e-04, Val Loss: 2.676e-04
# lr: 1.562e-04
# Epoch 591:
# Train Loss: 2.804e-04, Val Loss: 2.713e-04
# lr: 1.562e-04
# Epoch 592:
# Train Loss: 2.821e-04, Val Loss: 2.932e-04
# lr: 1.562e-04
# Epoch 593:
# Train Loss: 2.983e-04, Val Loss: 2.698e-04
# lr: 1.562e-04
# Epoch 594:
# Train Loss: 3.072e-04, Val Loss: 3.299e-04
# lr: 1.562e-04
# Epoch 595:
# Train Loss: 2.963e-04, Val Loss: 2.543e-04
# lr: 1.562e-04
# Epoch 596:
# Train Loss: 3.025e-04, Val Loss: 2.916e-04
# lr: 1.562e-04
# Epoch 597:
# Train Loss: 3.047e-04, Val Loss: 2.877e-04
# lr: 1.562e-04
# Epoch 598:
# Train Loss: 2.926e-04, Val Loss: 3.131e-04
# lr: 1.562e-04
# Epoch 599:
# Train Loss: 2.819e-04, Val Loss: 2.976e-04
# lr: 1.562e-04
# Epoch 600:
# Train Loss: 2.956e-04, Val Loss: 3.011e-04
# lr: 1.562e-04

# %%
# History
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
ax[0].plot(range(num_epochs), train_loss_hist)
ax[1].plot(range(num_epochs), val_loss_hist)
ax[0].set_title('Train Loss')
ax[1].set_title('Val Loss')
for axs in ax:
    axs.set_yscale('log')

# %% [markdown]
# ### 4. Assessment

# %% [markdown]
# #### 4.1 Accuracy of learned dynamics
#
# To begin with, we assess the accuracy of the learned dynamics. For that, we compare the predicted and true population change rates induced by the natural dynamics, as a function of the population size.

# %%
p = solution.y[0]

# True relationship
ground_truth = r*p*(1-p/k)

# Predicted relationship
with tf.device("CPU:0"):
    pred = ode_nn.predict(p, batch_size=128)

# %%
fig, ax = plt.subplots()
ax.plot(p, ground_truth, label='Ground Truth')
ax.plot(p, pred[1].flatten(), label='Predict')
ax.set_xlabel("Population Size", fontsize=16)
ax.set_ylabel("Population Change Rate", fontsize=16)
ax.legend();

# %% [markdown]
# #### 4.2 Long-term forecasting

# %% [markdown]
# Next, we test if the trained Neural ODE model can perform long-term integration given the initial population size used in training. Note that unlike the training phase, here, we **only** supply the trained model with the initial population size. The model will autoregressively predict the entire population evolution.
#
# First, let's define a helper function to make predictions with Neural ODE model.

# %%
@tf.function
def neuralODE_pred(p_init, t, ode_nn, h, H_max):
    """
    Using trained neural ODE to autogressively predict the population evolution.
    
    inputs:
    -------
    p_init: initial population size
    t: array of timestamps
    ode_nn: trained neural ODE model
    h: harvesting rate
    H_max: maximum harvesting capacity
    
    Outputs:
    --------
    preds: array of population evolution
    """

    preds = tf.TensorArray(dtype=tf.float32, size=tf.size(t))
    preds = preds.write(0, p_init)
    p = tf.constant([[p_init]], dtype=tf.float32)

    # Loop over time steps
    for i in tf.range(tf.size(t)-1):
        
        # Calculate time interval
        delta_t = t[i+1]-t[i]

        # Calculate population change rate
        _, natural_dynamics = ode_nn(p)
        dp_dt = natural_dynamics - tf.minimum(h*p, H_max)

        # Euler integration scheme
        p = p + delta_t*dp_dt

        # Store prediction
        preds = preds.write(i+1, p[0][0])

    return preds.stack()

# %% [markdown]
# Next, we simulate the population growth using the same setting employed during model training.

# %%
# Set parameters
r, k, h, H_max = 0.1, 1000, 0.01, 5

# Initial condition
p_0 = 20 

# Simulation time span
t_span = (0, 100)  
t_eval = np.linspace(t_span[0], t_span[1], 1000) 

# Solve ODE
solution = solve_ivp(logistic_growth, t_span, [p_0], 
                     t_eval=t_eval, args=(r, k, h, H_max))

# %%
# Neural ODE predictions
t_eval = t_eval.astype(np.float32)
predictions = neuralODE_pred(p_0, t_eval, ode_nn, h, H_max)

# %%
fig, ax = plt.subplots()
ax.plot(t_eval, solution.y[0], label='Truth')
ax.plot(t_eval, predictions, label='Predict')
ax.set_xlabel("Time (days)", fontsize=16)
ax.set_ylabel("Population Size", fontsize=16)
ax.legend();

# %% [markdown]
# #### 4.3 Dynamical modeling with different settings
#
# Finally, we test if the trained Neural ODE model can predict the population growth given a different set of initial condition and harvesting setting. Specifically, we set the new initial population as $p_0=60$, and the harvesting parameters $h=0.05$, $H_{max} = 40$.

# %% [markdown]
# We first simulate the population growth under the new setting.

# %%
# Set new harvesting parameters 
h_new, H_max_new = 0.05, 40

# Initial condition
p_0_new = 60 

# Simulation time span
t_span = (0, 100)  
t_eval = np.linspace(t_span[0], t_span[1], 1000) 

# Solve ODE
solution = solve_ivp(logistic_growth, t_span, [p_0_new], 
                     t_eval=t_eval, args=(r, k, h_new, H_max_new))

# %% [markdown]
# Afterward, we use the trained Neural ODE to predict the population growth.

# %%
# Neural ODE predictions
t_eval = t_eval.astype(np.float32)
predictions = neuralODE_pred(p_0_new, t_eval, ode_nn, h_new, H_max_new)

# %%
fig, ax = plt.subplots()
ax.plot(t_eval, solution.y[0], label='Truth')
ax.plot(t_eval, predictions, label='Predict')
ax.set_xlabel("Time (days)", fontsize=16)
ax.set_ylabel("Population Size", fontsize=16)
ax.legend();
